# %% [markdown]
# # Data Load

# %%
import pandas as pd
import os

# %%
os.chdir('/Users/aidenguerin/Desktop/projects/snow-vis/fit3179-vis02')

# %%
# Load csv
pass_info = pd.read_csv('web-scraping/data/pass_info.csv')
resort_elevation = pd.read_csv('web-scraping/data/raw_resort_elevation.csv')
resort_lifts = pd.read_csv('web-scraping/data/raw_resort_lifts.csv')
resort_locations = pd.read_csv('web-scraping/data/raw_resort_locations.csv')
resort_snowfall = pd.read_csv('web-scraping/data/raw_resort_snowfall.csv')
resort_terrain = pd.read_csv('web-scraping/data/raw_resort_terrain.csv')

# %%
# Create Master table
master = pass_info.merge(resort_lifts, on='short-name', how='left')
master = master.merge(resort_locations, on='short-name', how='left')
master = master.merge(resort_snowfall, on='short-name', how='left')
master = master.merge(resort_terrain, on='short-name', how='left')
master = master.merge(resort_elevation, on='short-name', how='left')

# %%
master
# Out:
#                     pass                    resort  \
# 0    mountain-collective             Alta Ski Area
# 1    mountain-collective            Aspen Snowmass
# 2    mountain-collective                   Big Sky
# 3    mountain-collective              Coronet Peak
# 4    mountain-collective              Jackson Hole
# ..                   ...                       ...
# 106            ikon-pass  The Summit at Snoqualmie
# 107            ikon-pass     Thredbo Alpine Resort
# 108            ikon-pass                 Tremblant
# 109            ikon-pass          Windham Mountain
# 110            ikon-pass               Winter Park
#
#                                                   link  \
# 0    https://www.onthesnow.com/utah/alta-ski-area/s...
# 1    https://www.onthesnow.com/colorado/aspen-snowm...
# 2    https://www.onthesnow.com/montana/big-sky-reso...
# 3    https://www.onthesnow.com/new-zealand/coronet-...
# 4    https://www.onthesnow.com/wyoming/jackson-hole...
# ..                                                 ...
# 106  https://www.onthesnow.com/washington/the-summi...
# 107  https://www.onthesnow.com/australia/thredbo-al...
# 108  https://www.onthesnow.com/quebec/tremblant/ski...
# 109  https://www.onthesnow.com/new-york/windham-mou...
# 110  https://www.onthesnow.com/colorado/winter-park...
#
#                    short-name  High Speed Quads  Triple Chairs  Double Chairs  \
# 0               alta-ski-area               3.0            1.0            2.0
# 1              aspen-snowmass              15.0            3.0            5.0
# 2              big-sky-resort               5.0            7.0            5.0
# 3                coronet-peak               2.0            NaN            NaN
# 4                jackson-hole               5.0            NaN            1.0
# ..                        ...               ...            ...            ...
# 106  the-summit-at-snoqualmie               2.0            3.0            6.0
# 107     thredbo-alpine-resort               4.0            NaN            2.0
# 108                 tremblant               6.0            1.0            NaN
# 109          windham-mountain               2.0            2.0            1.0
# 110        winter-park-resort               7.0            4.0            6.0
#
#      Gondolas &amp; Trams  High Speed Sixes  Quad Chairs  ...  \
# 0                     NaN               NaN          NaN  ...
# 1                     3.0               1.0          4.0  ...
# 2                     1.0               2.0          3.0  ...
# 3                     NaN               1.0          NaN  ...
# 4                     3.0               NaN          4.0  ...
# ..                    ...               ...          ...  ...
# 106                   NaN               NaN          4.0  ...
# 107                   NaN               NaN          NaN  ...
# 108                   3.0               NaN          1.0  ...
# 109                   NaN               1.0          NaN  ...
# 110                   1.0               2.0          NaN  ...
#
#      Skiable Terrain  Snow Making  Beginners Runs  Intermediate Runs  \
# 0            2614 ac       140 ac             NaN                NaN
# 1            5517 ac       658 ac             NaN                NaN
# 2            5800 ac       400 ac             15%                25%
# 3                NaN          NaN             17%                50%
# 4            2500 ac       195 ac              4%                41%
# ..               ...          ...             ...                ...
# 106          1994 ac         5 ac             15%                40%
# 107              NaN        72 ac             NaN                NaN
# 108           754 ac       465 ac             19%                30%
# 109           285 ac       280 ac             20%                48%
# 110          3081 ac       313 ac             24%                22%
#
#     Advanced Runs Expert Runs Night Skiing  Summit Vertical Drop   Base
# 0             NaN         NaN          NaN  11068'         2538'  8530'
# 1             NaN         NaN          NaN  12510'         4406'  8104'
# 2             42%         18%          NaN  11166'         4350'  7500'
# 3             26%         21%          NaN   5410'         1516'  3894'
# 4             38%         17%          NaN  10450'         4139'  6311'
# ..            ...         ...          ...     ...           ...    ...
# 106           45%         NaN       541 ac   3865'         1025'  2840'
# 107           NaN         NaN        15 ac   6683'         2205'  4478'
# 108           37%         13%          NaN   2871'         2116'   755'
# 109           19%         13%        45 ac   3100'         1600'  1500'
# 110           50%          4%          NaN  12060'         3060'  9000'
#
# [111 rows x 40 columns]

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Master Table

# %%
# Replace special characters in column name
master = master.rename(columns={'Gondolas &amp; Trams': 'Gondolas & Trams'})

# %%
# Create total chairs column
master['Total Lifts'] = master.iloc[:,4:11].sum(axis=1)

# %%
# Replace rowname where special characters are present
master.loc[master['short-name'] == 'folgarida-marilleva', 'resort'] = 'Folgarida Marilleva'

# %% [markdown]
# ### Terrain

# %%
# Strip symbols
resort_terrain['Beginners Runs'] = resort_terrain['Beginners Runs'].str.strip('%')
resort_terrain['Intermediate Runs'] = resort_terrain['Intermediate Runs'].str.strip('%')
resort_terrain['Advanced Runs'] = resort_terrain['Advanced Runs'].str.strip('%')
resort_terrain['Expert Runs'] = resort_terrain['Expert Runs'].str.strip('%')

# %%
# Melt dataframe
terrain_difficulty = resort_terrain[['short-name', 'Beginners Runs', 'Intermediate Runs', 'Advanced Runs', 'Expert Runs']].melt(id_vars='short-name', var_name='run_type', value_name='Percentage')

# %%
# Join pass information
terrain_difficulty = terrain_difficulty.merge(pass_info, on='short-name', how='left')

# %% [markdown]
# ### Snowfall

# %%
# Define function for returning snowfall in cm
def convert_to_cm(x):
    if '"' in x:
        unit = 'inch'
        value = x.replace('"', '')
        value = value.strip()
        amt = float(value) * 2.54
        return amt
    elif 'cm' in x:
        unit = 'cm'
        value = x.replace('cm', '')
        value = value.strip()
        amt = float(value)
        return amt

# %%
# Replace NaN with 0
resort_snowfall = resort_snowfall.fillna('0"')

# %%
# Apply function over month columns
for row in resort_snowfall.iterrows():
    for col in resort_snowfall.columns[1:]:
        resort_snowfall.loc[row[0], col] = convert_to_cm(resort_snowfall.loc[row[0], col])

# %%
# Melt dataframe
resort_snowfall = resort_snowfall.melt(id_vars='short-name', var_name='month', value_name='snowfall_cm').sort_values(by='snowfall_cm', ascending=False)

# %%
# Join pass information
resort_snowfall = resort_snowfall.merge(pass_info, on='short-name', how='left')

# %%
resort_snowfall
# Out:
#                     short-name month snowfall_cm                 pass  \
# 0                 jackson-hole   Feb      284.48  mountain-collective
# 1                 jackson-hole   Feb      284.48            ikon-pass
# 2          crystal-mountain-wa   Dec      284.48            ikon-pass
# 3                 jackson-hole   Dec      271.78  mountain-collective
# 4                 jackson-hole   Dec      271.78            ikon-pass
# ...                        ...   ...         ...                  ...
# 1327  the-summit-at-snoqualmie   Jun         0.0            ikon-pass
# 1328                 tremblant   Jun         0.0            ikon-pass
# 1329          windham-mountain   Jun         0.0            ikon-pass
# 1330             alta-ski-area   May         0.0  mountain-collective
# 1331             alta-ski-area   May         0.0            ikon-pass
#
#                         resort  \
# 0                 Jackson Hole
# 1                 Jackson Hole
# 2             Crystal Mountain
# 3                 Jackson Hole
# 4                 Jackson Hole
# ...                        ...
# 1327  The Summit at Snoqualmie
# 1328                 Tremblant
# 1329          Windham Mountain
# 1330             Alta Ski Area
# 1331             Alta Ski Area
#
#                                                    link
# 0     https://www.onthesnow.com/wyoming/jackson-hole...
# 1     https://www.onthesnow.com/wyoming/jackson-hole...
# 2     https://www.onthesnow.com/washington/crystal-m...
# 3     https://www.onthesnow.com/wyoming/jackson-hole...
# 4     https://www.onthesnow.com/wyoming/jackson-hole...
# ...                                                 ...
# 1327  https://www.onthesnow.com/washington/the-summi...
# 1328  https://www.onthesnow.com/quebec/tremblant/ski...
# 1329  https://www.onthesnow.com/new-york/windham-mou...
# 1330  https://www.onthesnow.com/utah/alta-ski-area/s...
# 1331  https://www.onthesnow.com/utah/alta-ski-area/s...
#
# [1332 rows x 6 columns]

# %% [markdown]
# # Export

# %%
# Export Master
master.to_csv('web-scraping/data/master.csv', index = False)

# Export terrain difficulty
terrain_difficulty.to_csv('web-scraping/data/terrain_difficulty.csv', index = False)

# Export terrain difficulty
resort_snowfall.to_csv('web-scraping/data/clean_resort_snowfall.csv', index = False)

# %%
for resort in master['resort'].drop_duplicates().sort_values():
    print(f'"{resort}",')
# Out:
# "Afton Alps",
# "Alpe Cimbra - Folgaria - Lavarone",
# "Alta Ski Area",
# "Andalo - Fai della Paganella",
# "Arapahoe Basin Ski Area",
# "Aspen Snowmass",
# "Bear Mountain",
# "Beaver Creek",
# "Big Sky",
# "Blue Mountain",
# "Boyne Mountain Resort",
# "Breckenridge",
# "Brides les Bains",
# "Brighton Resort",
# "Copper Mountain",
# "Coronet Peak",
# "Courchevel",
# "Crested Butte Mountain Resort",
# "Crystal Mountain",
# "Cypress Mountain",
# "Deer Valley Resort",
# "Eldora Mountain Resort",
# "Falls Creek Alpine Resort",
# "Fernie Alpine",
# "Folgarida Marilleva",
# "Heavenly",
# "Jackson Hole",
# "June Mountain",
# "Keystone",
# "Kicking Horse",
# "Killington Resort",
# "Kimberley",
# "Kirkwood",
# "La Tania",
# "Lake Louise",
# "Les Menuires",
# "Loon Mountain",
# "Madonna di Campiglio",
# "Mammoth Mountain",
# "Meribel",
# "Mont Sainte Anne",
# "Monte Bondone",
# "Mount Sunapee",
# "Mt. Bachelor",
# "Mt. Brighton",
# "Mt. Buller",
# "Mt. Hotham",
# "Mt. Norquay",
# "Nakiska Ski Area",
# "Nendaz",
# "Northstar California",
# "Okemo Mountain Resort",
# "Orelle",
# "Palisades Tahoe",
# "Panorama Mountain",
# "Park City",
# "Pejo",
# "Perisher",
# "Pinzolo",
# "Pontedilegno - Tonale",
# "Revelstoke",
# "Saint Martin de Belleville",
# "Snow Summit",
# "Snowbasin",
# "Snowbird",
# "Snowshoe Mountain",
# "Solitude Mountain Resort",
# "Steamboat",
# "Stevens Pass Resort",
# "Stoneham",
# "Stowe Mountain",
# "Stratton Mountain",
# "Sugarbush",
# "Sugarloaf",
# "Sun Valley",
# "Sunday River",
# "Sunshine Village",
# "Taos Ski Valley",
# "Telluride",
# "The Highlands",
# "The Remarkables",
# "The Summit at Snoqualmie",
# "Thredbo Alpine Resort",
# "Thyon 2000",
# "Tremblant",
# "Vail",
# "Val Thorens",
# "Valle Nevado",
# "Verbier",
# "Veysonnaz",
# "Whistler Blackcomb",
# "Wilmot Mountain",
# "Windham Mountain",
# "Winter Park",
